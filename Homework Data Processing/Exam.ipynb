# %%
import pandas as pd
import numpy as np

# %%
#####  REMARK THIS SECTION IF YOU ARE USING JUPITER NOTEBOOK OR VSCODE ######
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/Colab Notebooks/RAKAMIN PERSONAL/learning/Homework Data Processing
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/RAKAMIN PERSONAL/learning/Homework Data Processing

# %%
data = pd.read_csv('job_data_analyst_details.csv')
data.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %%
res = data[(data['Location'].str.contains('Houston'))]
res['Rating'].mean()
# Out:
# 3.2780821917808223

# %%
b = data[(data['Industry'] > 'Industry') & (data['Founded'] > 2015)]
b.groupby('Job Title').agg('count')
# Out:
#                                                     Unnamed: 0  \
# Job Title
# Ad Integrity Data Analyst-ATX                                1
# Bilingual (Chinese) Data Analyst                             1
# Billingual Chinese - Data Analyst                            1
# Business Data Analyst                                        1
# Data Analyst                                                 1
# Data Analyst (Finance)                                       1
# Data Governance Business Information Analyst                 1
# Data Scientist/Analyst - Wilbur Labs                         1
# Enterprise Data Office Analyst IV                            1
# Financial Data Analyst - Data Mining, Analytics...           1
# Junior Data Analyst                                          1
# Operations Data Analyst                                      1
# Principal Data Analyst, LATAM – Disney Streamin...           1
# Senior Analyst, Data Instrumentation & Quality ...           1
# ...

# %%
a = data[data['Founded'] == 2018]
b = data[data['Founded'] == 1995]
c = a.append(b)
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 36 to 2233
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         53 non-null     int64
#  1   Job Title          53 non-null     object
#  2   Salary Estimate    53 non-null     object
#  3   Job Description    53 non-null     object
#  4   Rating             53 non-null     float64
#  5   Company Name       53 non-null     object
#  6   Location           53 non-null     object
#  7   Headquarters       53 non-null     object
#  8   Founded            53 non-null     int64
#  9   Type of ownership  53 non-null     object
#  10  Industry           53 non-null     object
#  11  Revenue            53 non-null     object
#  12  Competitors        53 non-null     object
#  13  Easy Apply         53 non-null     object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 6.2+ KB
# ...

# %%
d = data[(data['Founded'] == 2017) & (data['Rating'] >= 3.5) & (data['Rating'] <= 4.5)]
d['new_rating'] = data['Rating']+0.5
d['new_rating'].mean()
# Out:
# <ipython-input-43-b11a2e6bad5a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['new_rating'] = data['Rating']+0.5
# 4.311111111111111

# %%
df1 = data[(data['Job Description'].str.contains('attitude')) & (data['Rating'] >= 1)]
df2 = data[(data['Location'] == 'New York, NY') & (data['Rating'] >= 1)]
df3 = df1.append(df2)
df3['Rating'].mean()
# Out:
# <ipython-input-47-76a0f30813ac>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df1.append(df2)
# 3.7101983002832855

# %%
asdf = data[(data['Location'].isin(['Lake Success, NY', 'Los Angeles, CA'])) & (data['Job Description'].str.contains('SQL'))]
asdf
# Out:
#      Unnamed: 0                            Job Title  \
# 234         234                         Data Analyst
# 238         238                         Data Analyst
# 247         247       Reporting Analyst Data Analyst
# 281         281               Encounter Data Analyst
# 366         366                      QA Data Analyst
# ..          ...                                  ...
# 660         660  Sr Performance Metrics Data Analyst
# 675         675  Sr Performance Metrics Data Analyst
# 676         676      Student Data Compliance Analyst
# 707         707             Systems and Data Analyst
# 714         714         Sr. Data Analyst — US Safety
#
#                   Salary Estimate  \
# 234    $41K-$78K (Glassdoor est.)
# 238    $41K-$78K (Glassdoor est.)
# 247    $45K-$88K (Glassdoor est.)
# 281    $84K-$90K (Glassdoor est.)
# 366   $77K-$132K (Glassdoor est.)
# ..                            ...
# 660    $65K-$81K (Glassdoor est.)
# 675    $65K-$81K (Glassdoor est.)
# ...

# %%
asdf.to_excel('analysis_result.csv')
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1143                 try:
# -> 1144                     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1145                     if engine == "auto":
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     262     def __call__(self, *args, **kwds) -> T:
# --> 263         return self.__func__(*args, **kwds)
#     264
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in _get_option(pat, silent)
#     134 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 135     key = _get_single_key(pat, silent)
#     136
#
# ...
