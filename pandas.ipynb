# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/Colab Notebooks/RAKAMIN PERSONAL/learning
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/RAKAMIN PERSONAL/learning

# %%
import pandas as pd

# %%
data = pd.read_csv('data/rakamin_customer.csv')

# %% [markdown]
# Operasi Dasar

# %%
data
# Out:
#     id_pelanggan                         nama  \
# 0              1  Fakhrul Fandy Widyaningtias
# 1              2          Ferdiansyah Amalina
# 2              3            Ficky Rizkyananta
# 3              4             Singgih Kharisma
# 4              5             Jeremiah Dinanti
# ..           ...                          ...
# 83            84                Janiar Satria
# 84            85               Retno Maulinda
# 85            86                  Abdul Gofar
# 86            87              Uswatun Hasanah
# 87            88                 Adi Putranto
#
#                                     email      telepon  umur bulan_lahir  \
# 0   fakhrulfandywidyaningtias@outlook.com   6285244454    27        Juni
# 1            ferdiansyahamalina@yahoo.com   6285244688    31     Agustus
# 2            fickyrizkyananta@hotmail.com   6285244922    15    Februari
# 3             singgihkharisma@hotmail.com   6285245156    49     Januari
# ...

# %%
#Melihat baris dan kolom
data.shape
# Out:
# (88, 10)

# %%
#get sum of row from data
data.shape[0]
# Out:
# 10

# %%
#get sum of column from data
data.shape[1]
# Out:
# 10

# %%
#Melihat info dasar dari data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_pelanggan        88 non-null     int64
#  1   nama                88 non-null     object
#  2   email               87 non-null     object
#  3   telepon             88 non-null     object
#  4   umur                88 non-null     int64
#  5   bulan_lahir         85 non-null     object
#  6   tanggal_registrasi  88 non-null     object
#  7   konfirmasi_telepon  88 non-null     int64
#  8   penipu              88 non-null     int64
#  9   pengguna_aktif      88 non-null     int64
# dtypes: int64(5), object(5)
# memory usage: 7.0+ KB

# %%
#melihat statistik sederhana
data.describe()
# Out:
#        id_pelanggan       umur  konfirmasi_telepon     penipu  pengguna_aktif
# count     88.000000  88.000000           88.000000  88.000000       88.000000
# mean      44.500000  31.568182            0.840909   0.045455        0.920455
# std       25.547342  10.892152            0.367857   0.209493        0.272139
# min        1.000000  15.000000            0.000000   0.000000        0.000000
# 25%       22.750000  22.750000            1.000000   0.000000        1.000000
# 50%       44.500000  31.500000            1.000000   0.000000        1.000000
# 75%       66.250000  40.000000            1.000000   0.000000        1.000000
# max       88.000000  50.000000            1.000000   1.000000        1.000000

# %%
#Melihat N baris pertama
data.head(10)
# Out:
#    id_pelanggan                         nama  \
# 0             1  Fakhrul Fandy Widyaningtias
# 1             2          Ferdiansyah Amalina
# 2             3            Ficky Rizkyananta
# 3             4             Singgih Kharisma
# 4             5             Jeremiah Dinanti
# 5             6              Ridhwan Noerani
# 6             7              Okky Oktaviaman
# 7             8      Dikposa Yosua Krisnanto
# 8             9                 Dhanu Rahman
# 9            10                    Bob Arisa
#
#                                    email     telepon  umur bulan_lahir  \
# 0  fakhrulfandywidyaningtias@outlook.com  6285244454    27        Juni
# 1           ferdiansyahamalina@yahoo.com  6285244688    31     Agustus
# 2           fickyrizkyananta@hotmail.com  6285244922    15    Februari
# 3            singgihkharisma@hotmail.com  6285245156    49     Januari
# 4          jeremiahdinanti@roketmail.com  6285245390    25     Januari
# ...

# %%
#Melihat N baris terakhir
data.tail(4)
# Out:
#     id_pelanggan             nama                        email      telepon  \
# 84            85   Retno Maulinda  retnomaulinda@roketmail.com   6285203303
# 85            86      Abdul Gofar            a.gofar@gmail.com  62815678555
# 86            87  Uswatun Hasanah                          NaN  62813688235
# 87            88     Adi Putranto         adiputranto@live.com  62852688775
#
#     umur bulan_lahir tanggal_registrasi  konfirmasi_telepon  penipu  \
# 84    28    November         2012-07-30                   1       0
# 85    33         NaN         2012-03-12                   1       0
# 86    23         NaN         2012-09-23                   0       0
# 87    29         NaN         2012-11-03                   1       0
#
#     pengguna_aktif
# 84               1
# 85               1
# 86               1
# 87               1

# %% [markdown]
# **MANIPULASI DATA**

# %%
data['telepon'] = data['telepon'].astype(float); # str,int,float
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_pelanggan        88 non-null     int64
#  1   nama                88 non-null     object
#  2   email               87 non-null     object
#  3   telepon             88 non-null     float64
#  4   umur                88 non-null     int64
#  5   bulan_lahir         85 non-null     object
#  6   tanggal_registrasi  88 non-null     object
#  7   konfirmasi_telepon  88 non-null     int64
#  8   penipu              88 non-null     int64
#  9   pengguna_aktif      88 non-null     int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 7.0+ KB

# %%
#merubah value null menjadi 0 pada kolom telepon
data['telepon'] = data['telepon'].fillna(0).astype(int)
data.head()
# Out:
#    id_pelanggan                         nama  \
# 0             1  Fakhrul Fandy Widyaningtias
# 1             2          Ferdiansyah Amalina
# 2             3            Ficky Rizkyananta
# 3             4             Singgih Kharisma
# 4             5             Jeremiah Dinanti
#
#                                    email     telepon  umur bulan_lahir  \
# 0  fakhrulfandywidyaningtias@outlook.com  6285244454    27        Juni
# 1           ferdiansyahamalina@yahoo.com  6285244688    31     Agustus
# 2           fickyrizkyananta@hotmail.com  6285244922    15    Februari
# 3            singgihkharisma@hotmail.com  6285245156    49     Januari
# 4          jeremiahdinanti@roketmail.com  6285245390    25     Januari
#
#   tanggal_registrasi  konfirmasi_telepon  penipu  pengguna_aktif
# 0         2012-02-18                   1       0               1
# 1         2012-06-29                   1       0               1
# 2         2013-06-04                   1       0               1
# ...

# %% [markdown]
# **String Conversion**
#
# Series.str.lower
# Converts all characters to lowercase.
#
# Series.str.upper
# Converts all characters to uppercase.
#
# Series.str.title
# Converts first character of each word to uppercase and remaining to lowercase.
#
# Series.str.capitalize
# Converts first character to uppercase and remaining to lowercase.
#
# Series.str.swapcase
# Converts uppercase to lowercase and lowercase to uppercase.
#
# Series.str.casefold
# Removes all case distinctions in the string.

# %%
#Merubah tipe data
data['nama'] = data['nama'].str.lower()
data.head()
# Out:
#    id_pelanggan                         nama  \
# 0             1  fakhrul fandy widyaningtias
# 1             2          ferdiansyah amalina
# 2             3            ficky rizkyananta
# 3             4             singgih kharisma
# 4             5             jeremiah dinanti
#
#                                    email     telepon  umur bulan_lahir  \
# 0  fakhrulfandywidyaningtias@outlook.com  6285244454    27        Juni
# 1           ferdiansyahamalina@yahoo.com  6285244688    31     Agustus
# 2           fickyrizkyananta@hotmail.com  6285244922    15    Februari
# 3            singgihkharisma@hotmail.com  6285245156    49     Januari
# 4          jeremiahdinanti@roketmail.com  6285245390    25     Januari
#
#   tanggal_registrasi  konfirmasi_telepon  penipu  pengguna_aktif
# 0         2012-02-18                   1       0               1
# 1         2012-06-29                   1       0               1
# 2         2013-06-04                   1       0               1
# ...

# %% [markdown]
# **Filtering Data**

# %%
#Filter beberapa kolom dalam data
data2 = data[['nama', 'email','telepon']]
data2.head()
# Out:
#                           nama                                  email  \
# 0  fakhrul fandy widyaningtias  fakhrulfandywidyaningtias@outlook.com
# 1          ferdiansyah amalina           ferdiansyahamalina@yahoo.com
# 2            ficky rizkyananta           fickyrizkyananta@hotmail.com
# 3             singgih kharisma            singgihkharisma@hotmail.com
# 4             jeremiah dinanti          jeremiahdinanti@roketmail.com
#
#       telepon
# 0  6285244454
# 1  6285244688
# 2  6285244922
# 3  6285245156
# 4  6285245390

# %%
#Menambahkan Kolom kedalam existing dataframe
df = pd.DataFrame({'no':[1,2,3,4,5,2],'nama' : ['Gisel', 'Surya', 'Dewi', 'Ridho', 'Alisa','Surya'], 'umur' : [21,26,17,28,25,26], 'alamat' : ['Darwin', 'Sydney', 'Adelaide', 'Perth', 'Tazmania','Sydney']})
df.head()
# Out:
#    no   nama  umur    alamat
# 0   1  Gisel    21    Darwin
# 1   2  Surya    26    Sydney
# 2   3   Dewi    17  Adelaide
# 3   4  Ridho    28     Perth
# 4   5  Alisa    25  Tazmania

# %%
#Menambahkan Kolom Baru
df['sepatu'] = [40,41,42,43,44,41]
df.head()
# Out:
#    no   nama  umur    alamat  sepatu
# 0   1  Gisel    21    Darwin      40
# 1   2  Surya    26    Sydney      41
# 2   3   Dewi    17  Adelaide      42
# 3   4  Ridho    28     Perth      43
# 4   5  Alisa    25  Tazmania      44

# %%
#Menambahkan Kolom baru dari Kolom Lainya
df['new_age'] = df['umur']
df.head()
# Out:
#    no   nama  umur    alamat  sepatu  new_age
# 0   1  Gisel    21    Darwin      40       21
# 1   2  Surya    26    Sydney      41       26
# 2   3   Dewi    17  Adelaide      42       17
# 3   4  Ridho    28     Perth      43       28
# 4   5  Alisa    25  Tazmania      44       25

# %%
#Menambahkan kolom dengan kombinasi kolom lainya

data['tahun_kelahiran'] = 2023 - data['umur'];
data.head()
# Out:
#    id_pelanggan                         nama  \
# 0             1  fakhrul fandy widyaningtias
# 1             2          ferdiansyah amalina
# 2             3            ficky rizkyananta
# 3             4             singgih kharisma
# 4             5             jeremiah dinanti
#
#                                    email     telepon  umur bulan_lahir  \
# 0  fakhrulfandywidyaningtias@outlook.com  6285244454    27        Juni
# 1           ferdiansyahamalina@yahoo.com  6285244688    31     Agustus
# 2           fickyrizkyananta@hotmail.com  6285244922    15    Februari
# 3            singgihkharisma@hotmail.com  6285245156    49     Januari
# 4          jeremiahdinanti@roketmail.com  6285245390    25     Januari
#
#   tanggal_registrasi  konfirmasi_telepon  penipu  pengguna_aktif  \
# 0         2012-02-18                   1       0               1
# 1         2012-06-29                   1       0               1
# ...

# %%
#Menghapus Satu Kolom
df = df.drop('new_age', axis=1)
df.head()
# Out:
#    no   nama  umur    alamat  sepatu
# 0   1  Gisel    21    Darwin      40
# 1   2  Surya    26    Sydney      41
# 2   3   Dewi    17  Adelaide      42
# 3   4  Ridho    28     Perth      43
# 4   5  Alisa    25  Tazmania      44

# %%
#Menghapus Lebih dari Satu Kolom
df = df.drop(['new_age','sepatu'], axis=1)
df.head()
# Out:
#    no   nama  umur    alamat
# 0   1  Gisel    21    Darwin
# 1   2  Surya    26    Sydney
# 2   3   Dewi    17  Adelaide
# 3   4  Ridho    28     Perth
# 4   5  Alisa    25  Tazmania

# %%
df.duplicated().any()
# Out:
# True

# %%
#Menampilkan data duplicate
df[df.duplicated(keep=False) == True]
# Out:
#    no   nama  umur  alamat  sepatu  new_age
# 1   2  Surya    26  Sydney      41       26
# 5   2  Surya    26  Sydney      41       26

# %%
#Menghapus data duplicate
df_clean = df.drop_duplicates()

# %%
#Check
df_clean.duplicated().any()
# Out:
# False

# %% [markdown]
# **Sorting dan Filtering**

# %%
#Sorting by single column
sorted = df.sort_values('umur', ascending=True)
sorted
# Out:
#    no   nama  umur    alamat  sepatu  new_age
# 2   3   Dewi    17  Adelaide      42       17
# 0   1  Gisel    21    Darwin      40       21
# 4   5  Alisa    25  Tazmania      44       25
# 1   2  Surya    26    Sydney      41       26
# 5   2  Surya    26    Sydney      41       26
# 3   4  Ridho    28     Perth      43       28

# %%
#Sorting by column
sorted = df.sort_values(['no','nama'], ascending=[True,False])
sorted
# Out:
#    no   nama  umur    alamat  sepatu  new_age
# 0   1  Gisel    21    Darwin      40       21
# 1   2  Surya    26    Sydney      41       26
# 5   2  Surya    26    Sydney      41       26
# 2   3   Dewi    17  Adelaide      42       17
# 3   4  Ridho    28     Perth      43       28
# 4   5  Alisa    25  Tazmania      44       25

# %%
#Filtering
filtered = data[data['umur'] < 25];
# filtered = data[data['email'] == "hilmanazalia@hotmail.com"];
filtered.head()
# Out:
#     id_pelanggan               nama                         email     telepon  \
# 2              3  ficky rizkyananta  fickyrizkyananta@hotmail.com  6285244922
# 12            13      hilman azalia      hilmanazalia@hotmail.com  6281911692
# 17            18       wahyu hayati         wahyuhayati@gmail.com  6289627184
# 22            23   muhamad pramanda   muhamadpramanda@outlook.com  6289633249
# 25            26         rian mufti         rianmufti@outlook.com  6287832903
#
#     umur bulan_lahir tanggal_registrasi  konfirmasi_telepon  penipu  \
# 2     15    Februari         2013-06-04                   1       0
# 12    17       Maret         2013-11-15                   1       0
# 17    23    Desember         2012-09-15                   1       1
# 22    16     Januari         2012-05-16                   1       0
# 25    24       April         2013-06-04                   1       0
#
#     pengguna_aktif  tahun_kelahiran
# 2                1             2008
# ...

# %%
filtered_sec = data[data['nama'].isin(['ficky rizkyananta','hilman azalia'])]
filtered_sec
# Out:
#     id_pelanggan               nama                         email     telepon  \
# 2              3  ficky rizkyananta  fickyrizkyananta@hotmail.com  6285244922
# 12            13      hilman azalia      hilmanazalia@hotmail.com  6281911692
#
#     umur bulan_lahir tanggal_registrasi  konfirmasi_telepon  penipu  \
# 2     15    Februari         2013-06-04                   1       0
# 12    17       Maret         2013-11-15                   1       0
#
#     pengguna_aktif  tahun_kelahiran
# 2                1             2008
# 12               1             2006

# %%
# filtered_null = data['nama'].isnull()
filtered_null = data['nama'].notnull()
filtered_null
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 83    True
# 84    True
# 85    True
# 86    True
# 87    True
# Name: nama, Length: 88, dtype: bool

# %%
#multiple column filter
new_filter = data[(data['umur'] > 28) & (data['bulan_lahir'].isin(['Agustus','Januari']))]
new_filter
# Out:
#     id_pelanggan                 nama                         email  \
# 1              2  ferdiansyah amalina  ferdiansyahamalina@yahoo.com
# 3              4     singgih kharisma   singgihkharisma@hotmail.com
# 5              6      ridhwan noerani    ridhwannoerani@hotmail.com
# 11            12       sutrisno rizal     sutrisnorizal@outlook.com
# 19            20      yutama riahdita      yutamariahdita@gmail.com
# 21            22      thomas geryance  thomasgeryance@roketmail.com
# 23            24        ramanta pasha        ramantapasha@gmail.com
# 29            30      herdaru junaidi    herdarujunaidi@outlook.com
# 59            60      hanifa ivangkia      hanifaivangkia@gmail.com
# 67            68      reny oktavianty      renyoktavianty@gmail.com
#
#        telepon  umur bulan_lahir tanggal_registrasi  konfirmasi_telepon  \
# 1   6285244688    31     Agustus         2012-06-29                   1
# 3   6285245156    49     Januari         2013-01-13                   1
# ...

# %% [markdown]
# **SQL Syntax Pandas Code Kegunaan**
#
# <column> = a df[ df[‘column’] == a ] or != / > / >= / < / <= Filter berdasarkan eksak nilai
#
# <column> in ( a, b, c) df[ df[‘column’].isin( [a, b, c] ) ] Filter multiple eksak nilai
#
# <column> is not null df[ df[‘column’].notnull() ] Filter supaya tidak ada null
#
# <column> is null df[ df[‘column’].isnull() ] Filter supaya null saja

# %%
#Single Filtering
# SQL Analogi - LIKE %
# untuk filter berdasarkan pattern/pola dari suatu kolom

new_filter = data[data['nama'].str.contains('junaidi')]
new_filter

#notes column harus bertipe string
# Out:
#     id_pelanggan             nama                       email     telepon  \
# 29            30  herdaru junaidi  herdarujunaidi@outlook.com  6287833839
#
#     umur bulan_lahir tanggal_registrasi  konfirmasi_telepon  penipu  \
# 29    50     Januari         2013-07-29                   1       0
#
#     pengguna_aktif  tahun_kelahiran
# 29               1             1973

# %%
# Single Filtering
# SQL Analogi - LIKE %
# untuk filter berdasarkan pattern/pola dari suatu kolom
data = data.dropna()
new_filter = data[data['email'].str.contains('yahoo.com')]
new_filter
# Out:
#     id_pelanggan                    nama                           email  \
# 1              2     ferdiansyah amalina    ferdiansyahamalina@yahoo.com
# 9             10               bob arisa              bobarisa@yahoo.com
# 16            17       rifqy butar-butar      rifqybutar-butar@yahoo.com
# 18            19          andi mayasopha         andimayasopha@yahoo.com
# 26            27   doni teddo prasetyani   doniteddoprasetyani@yahoo.com
# 28            29          rheza novianti         rhezanovianti@yahoo.com
# 39            40         garin sugiyanto        garinsugiyanto@yahoo.com
# 44            45             maruto asih            marutoasih@yahoo.com
# 45            46            azrul satria           azrulsatria@yahoo.com
# 50            51          athirah atsila         athirahatsila@yahoo.com
# 53            54     anindyanti bayhacki    anindyantibayhacki@yahoo.com
# 56            57           rianita santi          rianitasanti@yahoo.com
# ...

# %% [markdown]
# **Pattern**
#
# Pattern DIMULAI dengan: df[ df[‘column_name’].str.contains(‘^pattern’) ]
# Pattern DIAKHIRI dengan: df[ df[‘column_name’].str.contains(‘pattern$’) ]

# %%
#filter awalan dan akhiran mengandung sesuatu
#mencari data dengan kolom nama berawalan "a"
new_filter = data[data['nama'].str.contains('^a')]
new_filter
# Out:
#     id_pelanggan                  nama                              email  \
# 18            19        andi mayasopha            andimayasopha@yahoo.com
# 34            35      alfin chairunisa          alfinchairunisa@gmail.com
# 45            46          azrul satria              azrulsatria@yahoo.com
# 46            47           anton fikri             antonfikri@hotmail.com
# 47            48        anugrah sastra          anugrahsastra@outlook.com
# 50            51        athirah atsila            athirahatsila@yahoo.com
# 53            54   anindyanti bayhacki       anindyantibayhacki@yahoo.com
# 54            55  anastasia primanelza  anastasiaprimanelza@roketmail.com
# 55            56             anna usra             annausra@roketmail.com
# 60            61         amadea octaza         amadeaoctaza@roketmail.com
# 61            62         auzy narendra           auzynarendra@outlook.com
# 63            64  amalia widi abelardo     amaliawidiabelardo@outlook.com
# ...

# %%
#filter awalan dan akhiran mengandung sesuatu
#mencari data dengan kolom telepon berawalan "62853"
new_filter = data[data['telepon'].astype('str').str.contains('^62853')]
new_filter
# Out:
#     id_pelanggan                  nama                           email  \
# 62            63         rocitha mufti      rocithamufti@roketmail.com
# 63            64  amalia widi abelardo  amaliawidiabelardo@outlook.com
# 64            65          puspa fariza           puspafariza@yahoo.com
# 65            66           clara amira          claraamira@hotmail.com
# 66            67           hilary adha            hilaryadha@yahoo.com
# 67            68       reny oktavianty        renyoktavianty@gmail.com
# 68            69        salsabila resa       salsabilaresa@hotmail.com
# 69            70     fathina narimanda      fathinanarimanda@yahoo.com
#
#        telepon  umur bulan_lahir tanggal_registrasi  konfirmasi_telepon  \
# 62  6285347733    33       Maret         2012-12-26                   1
# 63  6285341168    17       Maret         2013-01-24                   1
# 64  6285334603    34       April         2012-08-14                   1
# ...
