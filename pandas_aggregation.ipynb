# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/Colab Notebooks/RAKAMIN PERSONAL/learning
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/RAKAMIN PERSONAL/learning

# %%
import pandas as pd

# %%
data = pd.read_excel('data/data_rakamin_customers.xlsx')

# %%
data.head()
# Out:
#   registration_id                         name  \
# 0      RK20202344  Fakhrul Fandy Widyaningtias
# 1      RK20202345          Ferdiansyah Amalina
# 2      RK20202346            Ficky Rizkyananta
# 3      RK20202347             Singgih Kharisma
# 4      RK20202348             Jeremiah Dinanti
#
#                                    email         phone   age  income_group  \
# 0  fakhrulfandywidyaningtias@outlook.com  6.285244e+09  27.0             2
# 1           ferdiansyahamalina@yahoo.com  6.285245e+09  31.0             3
# 2           fickyrizkyananta@hotmail.com  6.285245e+09  15.0             1
# 3            singgihkharisma@hotmail.com  6.285245e+09  49.0             4
# 4                    jeremia@rakamin.com  6.285245e+09  25.0             2
#
#    active                             city        province          hobby  \
# 0   False                    Tanjungpinang  Kepulauan Riau  Amateur radio
# 1    True                            Bogor      Jawa Barat      Animation
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   registration_id          107 non-null    object
#  1   name                     107 non-null    object
#  2   email                    107 non-null    object
#  3   phone                    104 non-null    float64
#  4   age                      106 non-null    float64
#  5   income_group             107 non-null    int64
#  6   active                   107 non-null    bool
#  7   city                     107 non-null    object
#  8   province                 107 non-null    object
#  9   hobby                    102 non-null    object
#  10  fav_movie                69 non-null     object
#  11  website_visit_count      107 non-null    int64
#  12  website_recency          107 non-null    int64
#  13  website_purchase_rate    107 non-null    float64
# ...

# %% [markdown]
# **statistics type**
#
# **count** menghitung total baris
#
# **nunique** menghitung total baris yang unique
#
# **mean** rata-rata dari kolom
#
# **median** median data dari kolom
#
# **min** nilai terkecil dari kolom
#
# **max** nilai maksimal dari kolom

# %%
#Ada berapa customer pada suatu provinsi
data.groupby('province').agg({'registration_id' : 'count'})
# Out:
#                     registration_id
# province
# Jakarta                          13
# Jambi                             2
# Jawa Barat                       22
# Jawa Tengah                      14
# Jawa Timur                       17
# Kalimantan Barat                  6
# Kalimantan Selatan                6
# Kalimantan Tengah                 3
# Kalimantan Timur                 10
# Kalimantan Utara                  1
# Kepulauan Riau                   10
# Lampung                           3

# %%
#Ada berapa unique customer pada suatu provinsi
data.groupby('province').agg({'registration_id' : 'nunique'})
# Out:
#                     registration_id
# province
# Jakarta                          12
# Jambi                             2
# Jawa Barat                       21
# Jawa Tengah                      13
# Jawa Timur                       16
# Kalimantan Barat                  4
# Kalimantan Selatan                6
# Kalimantan Tengah                 3
# Kalimantan Timur                 10
# Kalimantan Utara                  1
# Kepulauan Riau                   10
# Lampung                           3

# %%
#Ada berapa rata-rata umur pada suatu provinsi
data.groupby('province').agg({'age' : 'mean'})
# Out:
#                           age
# province
# Jakarta             33.166667
# Jambi               44.500000
# Jawa Barat          27.090909
# Jawa Tengah         31.357143
# Jawa Timur          37.470588
# Kalimantan Barat    40.500000
# Kalimantan Selatan  39.000000
# Kalimantan Tengah   33.333333
# Kalimantan Timur    26.100000
# Kalimantan Utara    50.000000
# Kepulauan Riau      35.500000
# Lampung             36.666667

# %%
#Ada berapa rata-rata umur per income_group
data.groupby('income_group').agg({'age' : 'mean'})
# Out:
#                     age
# income_group
# 1             17.894737
# 2             25.807692
# 3             35.407407
# 4             43.851852
# 5             51.571429

# %%
#Berapa median website_visit_count per income_group
data.groupby('income_group').agg({'website_visit_count' : 'median'})
# Out:
#               website_visit_count
# income_group
# 1                            47.0
# 2                            54.5
# 3                            36.0
# 4                            58.0
# 5                            46.0

# %%
#Berapa rata-rata , median , termuda dan tertua umur per province?
data.groupby('province').agg({'website_visit_count' : ['mean','median','min','max']})
# Out:
#                    website_visit_count
#                                   mean median min  max
# province
# Jakarta                      50.615385   44.0  17   98
# Jambi                        61.000000   61.0  30   92
# Jawa Barat                   50.045455   47.0   6   99
# Jawa Tengah                  38.428571   31.0   5   98
# Jawa Timur                   58.882353   58.0   9  100
# Kalimantan Barat             46.166667   46.0  20   76
# Kalimantan Selatan           49.000000   47.5   9   94
# Kalimantan Tengah            96.000000   95.0  94   99
# Kalimantan Timur             51.700000   60.0  11   97
# Kalimantan Utara             41.000000   41.0  41   41
# Kepulauan Riau               56.000000   57.0   9  100
# Lampung                      49.666667   63.0  20   66

# %%
#Berapa rata-rata , dan maksimum age per website_cs_call_count
data.groupby('website_cs_call_count').agg({'age' : ['mean','max']})
# Out:
#                              age
#                             mean   max
# website_cs_call_count
# 0                      33.240000  57.0
# 1                      28.714286  47.0
# 2                      35.125000  54.0
# 3                      33.562500  50.0

# %%
#Hitunglah banyaknya customer, rata-rata & median umur, dan
#website_purchase_rate minimum & maximum per income_group?
data.groupby('income_group').agg({'registration_id' : ['count'], 'age' : ['mean','median'], 'website_purchase_rate' : ['min','max']})
# Out:
#              registration_id        age        website_purchase_rate
#                        count       mean median                   min   max
# income_group
# 1                         19  17.894737   17.0                  0.00  1.00
# 2                         26  25.807692   25.5                  0.00  0.90
# 3                         27  35.407407   33.0                  0.33  0.98
# 4                         27  43.851852   44.0                  0.00  1.00
# 5                          8  51.571429   50.0                  0.00  0.99

# %%
# Hitunglah median website_recency, rata-rata website_purchase_amount,
# dan rata-rata website_visit_count per city?
data.groupby('city').agg({'website_recency' : ['median'], 'website_purchase_amount' : ['mean'], 'website_visit_count' : ['mean']})
# Out:
#                                   website_recency website_purchase_amount  \
#                                            median                    mean
# city
# Balikpapan                                   15.0            2.843333e+05
# Bandar Lampung                               17.0            3.780000e+05
# Bandung                                      23.0            7.620000e+05
# Banjar                                       15.5            1.520000e+05
# Banjarbaru                                    8.5            1.601750e+06
# Banjarmasin                                  24.5            1.296000e+06
# Batam                                         1.5            5.718333e+05
# Batu                                         16.0            6.000000e+05
# Bekasi                                       25.0            4.240000e+05
# Blitar                                       21.5            1.987250e+06
# Bogor                                         8.0            1.786667e+05
# ...

# %%
# Hitunglah banyaknya customer, rata-rata & median umur, dan
# website_purchase_rate minimum & maximum per province dan
# income_group?

data.groupby(['province','income_group']).agg({'registration_id' : ['nunique'],
                                               'age' : ['mean','median'],
                                               'website_purchase_rate' : ['min','max']})
# Out:
#                                 registration_id        age         \
#                                         nunique       mean median
# province           income_group
# Jakarta            1                          2  16.000000   16.0
#                    2                          3  25.500000   27.0
#                    3                          2  33.000000   33.0
#                    4                          3  47.000000   49.0
#                    5                          2  57.000000   57.0
# Jambi              4                          2  44.500000   44.5
# Jawa Barat         1                          8  17.444444   17.0
#                    2                          4  23.250000   21.0
#                    3                          5  34.000000   32.0
#                    4                          3  42.000000   40.0
#                    5                          1  50.000000   50.0
# Jawa Tengah        1                          3  20.000000   19.0
# ...

# %%
# Hitunglah median website_recency, rata-rata website_purchase_amount,
# dan rata-rata website_visit_count per province, city dan income_group?

data.groupby(['province','city']).agg({'registration_id' : ['nunique'],
                                               'age' : ['mean','median'],
                                               'website_purchase_rate' : ['min','max']})
# Out:
#                                                      registration_id  \
#                                                              nunique
# province           city
# Jakarta            Kota Administrasi Jakarta Barat                 2
#                    Kota Administrasi Jakarta Pusat                 3
#                    Kota Administrasi Jakarta Selatan               3
#                    Kota Administrasi Jakarta Timur                 1
#                    Kota Administrasi Jakarta Utara                 3
# Jambi              Sungai Penuh                                    2
# Jawa Barat         Bandung                                         2
#                    Banjar                                          2
#                    Bekasi                                          1
#                    Bogor                                           3
#                    Cimahi                                          2
# ...

# %%
# Hitunglah median website_recency, rata-rata website_purchase_amount,
# dan rata-rata website_visit_count per province, city dan income_group?

data.groupby(['province','city','income_group']).agg({'website_recency' : ['median'],
                                                      'website_purchase_amount' : ['mean'],
                                                      'website_visit_count' : ['mean']})
# Out:
#                                                             website_recency  \
#                                                                      median
# province       city                            income_group
# Jakarta        Kota Administrasi Jakarta Barat 4                        5.0
#                                                5                       19.0
#                Kota Administrasi Jakarta Pusat 1                       19.0
#                                                2                       57.0
#                                                4                       82.0
# ...                                                                     ...
# Kepulauan Riau Tanjungpinang                   2                       75.0
#                                                3                       20.0
# Lampung        Bandar Lampung                  4                       17.0
# ...

# %%
# data_res = data.reset_index()
data_res = data.reset_index(drop=True) #Supaya setelah reset index tidak menjadi kolom di dataframe
data_res
# Out:
#     registration_id                         name  \
# 0        RK20202344  Fakhrul Fandy Widyaningtias
# 1        RK20202345          Ferdiansyah Amalina
# 2        RK20202346            Ficky Rizkyananta
# 3        RK20202347             Singgih Kharisma
# 4        RK20202348             Jeremiah Dinanti
# ..              ...                          ...
# 102      RK20202440       Amalia Azizah Putriana
# 103      RK20202441               Didin Suherdin
# 104      RK20202442            Amelia Sari Putri
# 105      RK20202443               Puspita Amalia
# 106      RK20202444               Puspita Amalia
#
#                                      email         phone   age  income_group  \
# 0    fakhrulfandywidyaningtias@outlook.com  6.285244e+09  27.0             2
# 1             ferdiansyahamalina@yahoo.com  6.285245e+09  31.0             3
# 2             fickyrizkyananta@hotmail.com  6.285245e+09  15.0             1
# ...

# %%
#mereset hasil describe
df_group_by_reset = data.groupby(['province','city','income_group']).agg({'website_recency' : ['median'],
                                                      'website_purchase_amount' : ['mean'],
                                                      'website_visit_count' : ['mean']})
df_group_by_reset = df_group_by_reset.reset_index()
df_group_by_reset
# Out:
#           province                             city income_group  \
#
# 0          Jakarta  Kota Administrasi Jakarta Barat            4
# 1          Jakarta  Kota Administrasi Jakarta Barat            5
# 2          Jakarta  Kota Administrasi Jakarta Pusat            1
# 3          Jakarta  Kota Administrasi Jakarta Pusat            2
# 4          Jakarta  Kota Administrasi Jakarta Pusat            4
# ..             ...                              ...          ...
# 72  Kepulauan Riau                    Tanjungpinang            2
# 73  Kepulauan Riau                    Tanjungpinang            3
# 74         Lampung                   Bandar Lampung            4
# 75         Lampung                            Metro            1
# 76         Lampung                            Metro            4
#
#    website_recency website_purchase_amount website_visit_count
#             median                    mean                mean
# ...

# %%
#How to rename column name
df_customers = data.rename(columns = {'age' : 'usia_customer'}) #kalau ingin merubah banyak column tinggal pisahkan saja dengan comma dengan format json
df_customers
# Out:
#     registration_id                         name  \
# 0        RK20202344  Fakhrul Fandy Widyaningtias
# 1        RK20202345          Ferdiansyah Amalina
# 2        RK20202346            Ficky Rizkyananta
# 3        RK20202347             Singgih Kharisma
# 4        RK20202348             Jeremiah Dinanti
# ..              ...                          ...
# 102      RK20202440       Amalia Azizah Putriana
# 103      RK20202441               Didin Suherdin
# 104      RK20202442            Amelia Sari Putri
# 105      RK20202443               Puspita Amalia
# 106      RK20202444               Puspita Amalia
#
#                                      email         phone  usia_customer  \
# 0    fakhrulfandywidyaningtias@outlook.com  6.285244e+09           27.0
# 1             ferdiansyahamalina@yahoo.com  6.285245e+09           31.0
# 2             fickyrizkyananta@hotmail.com  6.285245e+09           15.0
# 3              singgihkharisma@hotmail.com  6.285245e+09           49.0
# ...

# %%
pd.pivot_table(df_customers,
               index=['income_group'],
               values=['registration_id','usia_customer','website_purchase_rate'],
               aggfunc={'registration_id' : ['nunique'],
                        'usia_customer' : ['mean','median'],
                        'website_purchase_rate' : ['min', 'max']
                        })
# Out:
#              registration_id usia_customer        website_purchase_rate
#                      nunique          mean median                   max   min
# income_group
# 1                         18     17.894737   17.0                  1.00  0.00
# 2                         25     25.807692   25.5                  0.90  0.00
# 3                         26     35.407407   33.0                  0.98  0.33
# 4                         26     43.851852   44.0                  1.00  0.00
# 5                          6     51.571429   50.0                  0.99  0.00

# %%
df_customers
# Out:
#     registration_id                         name  \
# 0        RK20202344  Fakhrul Fandy Widyaningtias
# 1        RK20202345          Ferdiansyah Amalina
# 2        RK20202346            Ficky Rizkyananta
# 3        RK20202347             Singgih Kharisma
# 4        RK20202348             Jeremiah Dinanti
# ..              ...                          ...
# 102      RK20202440       Amalia Azizah Putriana
# 103      RK20202441               Didin Suherdin
# 104      RK20202442            Amelia Sari Putri
# 105      RK20202443               Puspita Amalia
# 106      RK20202444               Puspita Amalia
#
#                                      email         phone  usia_customer  \
# 0    fakhrulfandywidyaningtias@outlook.com  6.285244e+09           27.0
# 1             ferdiansyahamalina@yahoo.com  6.285245e+09           31.0
# 2             fickyrizkyananta@hotmail.com  6.285245e+09           15.0
# 3              singgihkharisma@hotmail.com  6.285245e+09           49.0
# ...
