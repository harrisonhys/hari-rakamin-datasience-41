# %%
sold = 1020
pos_feed = 575

if sold >= 1000:
  if(pos_feed > 600):
    print('Seler Premium')
  else:
    print('Bukan Seler Premium')
else:
  print('Bukan Seler Premium')
# Out:
# Bukan Seler Premium

# %%
recency = 65
frequent = 1
monetary = 120000

if recency > 60:
    if frequent < 2:
        if monetary < 125000:
            print('Eligible')
        else:
            print('Not eligible')
    else:
        print('Not eligible')
else:
    print('Not eligible')
# Out:
# Eligible
